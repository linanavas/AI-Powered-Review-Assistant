# %%
#!pip install streamlit openai pandas pyngrok tiktoken

# %%
#!pip install "langchain==0.2.12" "langchain-core==0.2.39"

# %%
#!pip install "langchain-community==0.2.12"

# %%
import os
from google.colab import userdata
from pyngrok import ngrok

api_key = userdata.get('OPENAI_API_KEY')
ngrok_token = userdata.get('NGROK_TOKEN')
os.environ['OPENAI_API_KEY'] = api_key
ngrok.set_auth_token(ngrok_token)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Final Project BBS
# Out:
# /content/drive/MyDrive/Final Project BBS

# %%
# !pkill streamlit
# !nohup streamlit run app.py --server.port=8501 --server.headless true >/dev/null 2>&1 &

# %%
public_url = ngrok.connect(8501)
public_url
# Out:
# <NgrokTunnel: "https://kelvin-photoheliographic-overstoutly.ngrok-free.dev" -> "http://localhost:8501">
